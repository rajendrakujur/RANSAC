# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ### The equation of line

# %%
def line(a, b, x):
    return a*x + b

# %% [markdown]
# ### Generating the dataset where alpha is the fraction of points of outliers and sigma is the variance of noise

# %%
def generateDataSet(a, b, x_min, x_max, n, alpha, sigma):

    x = (np.array([(np.random.random()-0.5)*10 for i in range(n)])).reshape(n,1)
    
    # Since alpha is fraction of outliers present
    number_of_outliers = int(alpha*n)
    # assumed 50% points more than outliers are noise
    number_of_noise = int((alpha + 0.5)*n)
    # remaining points
    number_of_inliners = n - number_of_outliers - number_of_noise
    
    # generate y_actual valeus
    y_actual = line(a, b, x[:number_of_inliners])
    
    # generate y_noise values
    y_noise = line(a, b, x[number_of_inliners:number_of_inliners + number_of_noise]) + sigma * np.random.normal(0, 1, (number_of_noise,1))
    
    sequence = [-20, 20]
    # generate y_outliers
    y_outlier = line(a, b, x[number_of_inliners + number_of_noise:]) + sigma*np.random.normal(0, 1, (number_of_outliers,1)) + (np.random.choice(sequence, number_of_outliers)).reshape(number_of_outliers, 1)
    
    # Plot all the points
    plt.plot(x[:number_of_inliners,:],y_actual,'bo',x[number_of_inliners:number_of_inliners+number_of_noise,:],y_noise,'bo',x[number_of_inliners+number_of_noise:,:],y_outlier,'ro')
    plt.title(f'Points at alpha = {alpha}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    
    return x, y_outlier, y_noise, y_actual

x, y_outlier, y_noise, y_actual = generateDataSet(2, 3, -5, 5, 100, 0.2, 1)

# %%
# First concatenate all of the co-ordinates
y = np.concatenate((y_actual,y_noise,y_outlier))

# faltten x and y 
x = (x).flatten()
y = (y).flatten()

# %% [markdown]
# ### Equation of line in the form of Ax + By + C = 0

# %%
# returns the y value from the given line Ax + By + C = 0
def line(A, B, C, x):
    return (-C/B) - (A/B)*x

# %% [markdown]
# ### To generate random indices and make a line between those points

# %%
# Randomly generates two points indices
def randomIndexGenerator():
    first_point_index = random.randint(0, 99)
    second_point_index = random.randint(0, 99)
    
    while first_point_index == second_point_index:
        second_point_index = random.randint(0, 99)
    return x[first_point_index], y[first_point_index], x[second_point_index], y[second_point_index]

# %% [markdown]
# ### Main function where the execution begins

# %%
iterations = 100
tolerance = 1
count_inliers = []
point_x = []
point_y = []


for _ in range(iterations):
    x1, y1, x2, y2 = randomIndexGenerator()
    
    # line equation is (y1-y2)*x + (x2-x1)*y + (x1*y2 -x2*y1) = 0 in the form of Ax + By + C = 0
    A = y1 - y2
    B = x2 - x1
    C = x1*y2 - x2*y1
    
    # Now lets find each points distance from the line forming by choosing these two points
    # from formula |Ax + By + C| /((A**2 + B**2)**0.5)
    inliers = 0
    for index in range(len(x)):
        distance = abs(A*x[index] + B*y[index] + C)/ ((A**2 + B**2) ** 0.5)
        if distance < tolerance:
            inliers += 1
    
    print(f'Iteration number : {_+1}',end=' ')
    print(f'Number of inliers : {inliers}')
    
    # store each iteration's inliers count and x and y co ordinates for last 
    count_inliers.append(inliers)
    point_x.append([x1, x2])
    point_y.append([y1, y2])
    
    # To store the current points co ordinates an make a line joining them 
    line_x_coordinate = [x1, x2]
    line_y_coordinate = [y1, y2]
    
    # Plot the graph at each iteration
    # for all the points make scatter graph
    plt.scatter(x,y)
    # for the generated points make a line joining both the points
    plt.plot(line_x_coordinate, line_y_coordinate, 'red', linewidth = 2.0)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f'Iteration Number {_+1}')
    plt.show()
    
    print('************************************************************************************************')
    
max_in = max(count_inliers)
print(f'Highest number of inliers : {max_in}')

# Find the index which is having highest number of inliners so that corresponding line can be drawn
index = count_inliers.index(max_in)

# fetch x and y coordinates of both points
x1, x2 = point_x[index][0], point_x[index][1] 
y1, y2 = point_y[index][0], point_y[index][1]

# Now form the equation of line
# line equation is (y1-y2)*x + (x2-x1)*y + (x1*y2 -x2*y1) = 0 in the form of Ax + By + C = 0
A = y1 - y2
B = x2 - x1
C = x1*y2 - x2*y1

# make equally spaced x points
line_x = np.linspace(-5, 5, 100)
# for every x calculate y values
line_y = [line(A, B, C, x) for x in line_x]

# plot the line from x_min ot x_max with the calcuated line equation
plt.plot(line_x, line_y, 'red')
plt.scatter(x, y)
plt.title(f'Plot with Highest number of inliers in {iterations} iterations')
plt.xlabel('x')
plt.ylabel(f'y')
plt.show()
# Out:
# Iteration number : 1 Number of inliers : 26
# ************************************************************************************************
# Iteration number : 2 Number of inliers : 25
# ************************************************************************************************
# Iteration number : 3 Number of inliers : 19
# ************************************************************************************************
# Iteration number : 4 Number of inliers : 8
# ************************************************************************************************
# Iteration number : 5 Number of inliers : 39
# ************************************************************************************************
# Iteration number : 6 Number of inliers : 25
# ************************************************************************************************
# Iteration number : 7 Number of inliers : 26
# ************************************************************************************************
# Iteration number : 8 Number of inliers : 13
# ************************************************************************************************
# Iteration number : 9 Number of inliers : 18
# ************************************************************************************************
# Iteration number : 10 Number of inliers : 19
# ************************************************************************************************
# Iteration number : 11 Number of inliers : 58
# ************************************************************************************************
# Iteration number : 12 Number of inliers : 80
# ************************************************************************************************
# Iteration number : 13 Number of inliers : 68
# ************************************************************************************************
# Iteration number : 14 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 15 Number of inliers : 77
# ************************************************************************************************
# Iteration number : 16 Number of inliers : 26
# ************************************************************************************************
# Iteration number : 17 Number of inliers : 31
# ************************************************************************************************
# Iteration number : 18 Number of inliers : 17
# ************************************************************************************************
# Iteration number : 19 Number of inliers : 24
# ************************************************************************************************
# Iteration number : 20 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 21 Number of inliers : 37
# ************************************************************************************************
# Iteration number : 22 Number of inliers : 78
# ************************************************************************************************
# Iteration number : 23 Number of inliers : 37
# ************************************************************************************************
# Iteration number : 24 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 25 Number of inliers : 26
# ************************************************************************************************
# Iteration number : 26 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 27 Number of inliers : 74
# ************************************************************************************************
# Iteration number : 28 Number of inliers : 74
# ************************************************************************************************
# Iteration number : 29 Number of inliers : 5
# ************************************************************************************************
# Iteration number : 30 Number of inliers : 18
# ************************************************************************************************
# Iteration number : 31 Number of inliers : 17
# ************************************************************************************************
# Iteration number : 32 Number of inliers : 65
# ************************************************************************************************
# Iteration number : 33 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 34 Number of inliers : 77
# ************************************************************************************************
# Iteration number : 35 Number of inliers : 8
# ************************************************************************************************
# Iteration number : 36 Number of inliers : 22
# ************************************************************************************************
# Iteration number : 37 Number of inliers : 18
# ************************************************************************************************
# Iteration number : 38 Number of inliers : 75
# ************************************************************************************************
# Iteration number : 39 Number of inliers : 69
# ************************************************************************************************
# Iteration number : 40 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 41 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 42 Number of inliers : 74
# ************************************************************************************************
# Iteration number : 43 Number of inliers : 27
# ************************************************************************************************
# Iteration number : 44 Number of inliers : 34
# ************************************************************************************************
# Iteration number : 45 Number of inliers : 30
# ************************************************************************************************
# Iteration number : 46 Number of inliers : 77
# ************************************************************************************************
# Iteration number : 47 Number of inliers : 78
# ************************************************************************************************
# Iteration number : 48 Number of inliers : 10
# ************************************************************************************************
# Iteration number : 49 Number of inliers : 23
# ************************************************************************************************
# Iteration number : 50 Number of inliers : 64
# ************************************************************************************************
# Iteration number : 51 Number of inliers : 9
# ************************************************************************************************
# Iteration number : 52 Number of inliers : 55
# ************************************************************************************************
# Iteration number : 53 Number of inliers : 27
# ************************************************************************************************
# Iteration number : 54 Number of inliers : 55
# ************************************************************************************************
# Iteration number : 55 Number of inliers : 34
# ************************************************************************************************
# Iteration number : 56 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 57 Number of inliers : 23
# ************************************************************************************************
# Iteration number : 58 Number of inliers : 23
# ************************************************************************************************
# Iteration number : 59 Number of inliers : 34
# ************************************************************************************************
# Iteration number : 60 Number of inliers : 53
# ************************************************************************************************
# Iteration number : 61 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 62 Number of inliers : 49
# ************************************************************************************************
# Iteration number : 63 Number of inliers : 33
# ************************************************************************************************
# Iteration number : 64 Number of inliers : 21
# ************************************************************************************************
# Iteration number : 65 Number of inliers : 27
# ************************************************************************************************
# Iteration number : 66 Number of inliers : 12
# ************************************************************************************************
# Iteration number : 67 Number of inliers : 20
# ************************************************************************************************
# Iteration number : 68 Number of inliers : 34
# ************************************************************************************************
# Iteration number : 69 Number of inliers : 76
# ************************************************************************************************
# Iteration number : 70 Number of inliers : 18
# ************************************************************************************************
# Iteration number : 71 Number of inliers : 3
# ************************************************************************************************
# Iteration number : 72 Number of inliers : 61
# ************************************************************************************************
# Iteration number : 73 Number of inliers : 21
# ************************************************************************************************
# Iteration number : 74 Number of inliers : 21
# ************************************************************************************************
# Iteration number : 75 Number of inliers : 30
# ************************************************************************************************
# Iteration number : 76 Number of inliers : 72
# ************************************************************************************************
# Iteration number : 77 Number of inliers : 15
# ************************************************************************************************
# Iteration number : 78 Number of inliers : 77
# ************************************************************************************************
# Iteration number : 79 Number of inliers : 27
# ************************************************************************************************
# Iteration number : 80 Number of inliers : 18
# ************************************************************************************************
# Iteration number : 81 Number of inliers : 62
# ************************************************************************************************
# Iteration number : 82 Number of inliers : 75
# ************************************************************************************************
# Iteration number : 83 Number of inliers : 11
# ************************************************************************************************
# Iteration number : 84 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 85 Number of inliers : 19
# ************************************************************************************************
# Iteration number : 86 Number of inliers : 22
# ************************************************************************************************
# Iteration number : 87 Number of inliers : 77
# ************************************************************************************************
# Iteration number : 88 Number of inliers : 33
# ************************************************************************************************
# Iteration number : 89 Number of inliers : 38
# ************************************************************************************************
# Iteration number : 90 Number of inliers : 18
# ************************************************************************************************
# Iteration number : 91 Number of inliers : 36
# ************************************************************************************************
# Iteration number : 92 Number of inliers : 62
# ************************************************************************************************
# Iteration number : 93 Number of inliers : 20
# ************************************************************************************************
# Iteration number : 94 Number of inliers : 25
# ************************************************************************************************
# Iteration number : 95 Number of inliers : 77
# ************************************************************************************************
# Iteration number : 96 Number of inliers : 77
# ************************************************************************************************
# Iteration number : 97 Number of inliers : 31
# ************************************************************************************************
# Iteration number : 98 Number of inliers : 77
# ************************************************************************************************
# Iteration number : 99 Number of inliers : 79
# ************************************************************************************************
# Iteration number : 100 Number of inliers : 74
# ************************************************************************************************
# Highest number of inliers : 80
